# %%
import runDAQ

num_subruns=4
num_events=500
## Threshold in mV
threshold=100
## Simple daq mode (single channel trigger with fixed threshold)
daq_mode=3
file_name='hoge'

runDAQ.setParameters(num_subruns,num_events,threshold,daq_mode,file_name)
runDAQ.main()
# Out:
# max samples 400
# Read ch status
# [True, True, False, False]
# Trig ch status
# [False, True, False, False]
# Number of events to be collected:  500
# Pulse Voltage= 700.0  [mV], Pulse Rate= 20.0  [MHz]
# 1
# Init ch 0
# setChA   6   2
# Init ch 1
# setChB   7   2
# Trigger ch:  1
# threshold= 100.0 , ( 1626  in COUNT)
# Polarity =  1
# Sub run:  0 / 4
# integration from  80.0000011920929  to  136.00000202655792  [ns]
# Trigger rate =  184.16756716645318  Hz
# Mean of max height =  677.0247469066368  mV
# RunDaq Time =  3.7656774520874023
# Sub run:  1 / 4
# integration from  80.0000011920929  to  136.00000202655792  [ns]
# Trigger rate =  197.02062892280554  Hz
# Mean of max height =  670.9932508436445  mV
# RunDaq Time =  3.330009937286377
# Sub run:  2 / 4
# integration from  80.0000011920929  to  136.00000202655792  [ns]
# Trigger rate =  195.7916162635491  Hz
# Mean of max height =  667.1304836895389  mV
# RunDaq Time =  3.285736083984375
# Sub run:  3 / 4
# integration from  80.0000011920929  to  136.00000202655792  [ns]
# Trigger rate =  192.74029259476904  Hz
# Mean of max height =  671.192125984252  mV
# RunDaq Time =  3.4001946449279785
# {'openunit': 0, 'setChA': 0, 'setChB': 0, 'trigger': 0, 'GetTimebase': 0, 'MemorySegments': 0, 'SetNoOfCaptures': 0, 'runBlock': 0, 'isReady': 0, 'setDataBuffersA': 0, 'setDataBuffersB': 0, 'getValues': 0, 'stop': 0, 'close': 0}
